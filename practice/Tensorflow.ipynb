# %% [markdown]
# ## TensorFlow Practice
#
# hello_constant = tf.constant('Hello World!'), hello_constant is a 0-dimensional string tensor
#
# ` tf.constant()` is called a constant tensor, because the value of the tensor never changes.
#
# ### Session
#
# ` tf.Session()` ![image.png](attachment:image.png)
#
# The session is in charge of allocating the operations to GPU(s) and/or CPU(s).

# %%
import tensorflow as tf

# Create TensorFlow object called hello_constant
hello_constant = tf.constant('Hello World!')

with tf.Session() as sess:
    # Run the tf.constant operation in the session
    output = sess.run(hello_constant)
    print(output)
# Out:
# b'Hello World!'

# %% [markdown]
# The code has already created the tensor, `hello_constant`, from the previous lines. The next step is to evaluate the tensor in a session.
#
# The code creates a session instance, sess, using `tf.Session`. The `sess.run()` function then evaluates the tensor and returns the results.

# %% [markdown]
# ## Inputs

# %% [markdown]
# `tf.placeholder()` returns a tensor that gets its value from data passed to the `tf.session.run()` function, allowing you to set the input right before the session runs.
#
# The `feed_dict` parameter in `tf.session.run()` to sets the placeholder tensor

# %%
x = tf.placeholder(tf.string)

with tf.Session() as sess:
    output = sess.run(x, feed_dict={x: 'Hello World'})
    
print(output)
# Out:
# Hello World

# %%
import tensorflow as tf


def run():
    output = None
    x = tf.placeholder(tf.int32)

    with tf.Session() as sess:
        # TODO: Feed the x tensor 123
        output = sess.run(x, feed_dict={x:123})

    return output

# %%
import tensorflow as tf

# TODO: Convert the following to TensorFlow:
'''
x = 10
y = 2
z = x/y - 1
'''
# TODO: Print z from a session
x = tf.constant(10)
y = tf.constant(2)
z = tf.cast(tf.divide(x,y), tf.int32) - tf.constant(1)

with tf.Session() as sess:
    output = sess.run(z)
    print(output)
# Out:
# 4

# %% [markdown]
# ## Variables
#
# Whn a tensor needs to be modified `tf.placeholder()` or `tf.constant()` can't serve the purpose. For this purpose `tf.Variable()` is used.

# %%
#Usage:

x = tf.Variable(5)

# %% [markdown]
# `tf.Variable()` class creates "x" tensor with intial value of "5".
#
# "x" has to intialized before running the session. In fact, initalization of all the global variables has to be done before running a session.
#
# Intialization of global variables is done by `tf.gobal_variables_intialializer()`
#
# The `tf.global_variables_initializer()` call returns an operation that will initialize all TensorFlow variables from the graph.

# %%
# initialization:

init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)

# %% [markdown]
# ## Cross Entropy

# %%
softmax_data = [0.7, 0.2, 0.1]
one_hot_data = [1.0, 0.0, 0.0]

softmax = tf.placeholder(tf.float32)
one_hot = tf.placeholder(tf.float32)

# TODO: Print cross entropy from session

x = -1*tf.reduce_sum(one_hot_data*tf.log(softmax))

with tf.Session() as sess:
    output = sess.run(x, feed_dict={softmax:softmax_data, one_hot:one_hot_data})

print(output)
# Out:
# 0.356675
